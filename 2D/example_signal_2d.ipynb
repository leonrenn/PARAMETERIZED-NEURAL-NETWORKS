# %% [markdown]
# # Example Signal for 2D
# ---
# Scatter plots for sampling 1000 points from simple gaussian with different $\mu$'s but same $\sigma$'s.<br>
# The $\mu$'s will differ for the data and span on a range from 0 to 1 in 2D. <br>
# It might be the case that the data can be well seperate, but if the means are the same for the gaussian peaks is similar
# This task can hardly be done. The Neural Network should paramterize on the whole span on which it was trained on without havin t trained on _all_ combinations.

# %% [markdown]
# ### Import Modules

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Plot Signals
#
# Signal and background event visualization.

# %%
np.random.seed(42)
sizes = 1000
signals = [[0, 0], [0, 0.5], [0.5, 0], [0.5, 0.5]]
cov = np.array([[0.02, 0],[0, 0.02]])
labels = ["[0, 0]", "[0, 0.5]", "[0.5, 0]", "[0.5, 0.5]"]
data = [np.random.multivariate_normal(signal, cov, size=sizes) for signal in signals]
for idx, d in enumerate(data):
    plt.scatter(d[:, 0], d[:, 1], label=f"H: {labels[idx]}")
plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
